# %% [markdown]
# # Gluon CIFAR-10 Trained in Local Mode
# _**ResNet model in Gluon trained locally in a notebook instance**_
#
# ---
#
# ---
#
# _This notebook was created and tested on an ml.p3.8xlarge notebook instance._
#
# ## Setup
#
# Import libraries and set IAM role ARN.

# %%
# %%time
import sagemaker
import boto3
import pandas
import re
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.mxnet import MXNet

role = "arn:aws:iam::437242975833:role/service-role/AmazonSageMaker-ExecutionRole-20180711T133970"
sagemaker_session = sagemaker.Session()
# inputs = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-gluon-cifar10')


bucket='sagemaker-crops-corn' # customize to your bucket

training_image = get_image_uri(boto3.Session().region_name, 'image-classification')
# Out:
# CPU times: user 770 ms, sys: 821 ms, total: 1.59 s
# Wall time: 561 ms

# %% [markdown]
# Install pre-requisites for local training.

# %%
# !/bin/bash setup.sh
# Out:
# The user has root access.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# TEST1
# nvidia-docker2 already installed. We are good to go!

# %% [markdown]
# ---
#
# ## Data
#
# We use the helper scripts to download CIFAR-10 training data and sample images.

# %%
from cifar10_utils import download_training_data
download_training_data()
# Out:
# downloading training data...
# done

# %% [markdown]
# We use the `sagemaker.Session.upload_data` function to upload our datasets to an S3 location. The return value `inputs` identifies the location -- we will use this later when we start the training job.
#
# Even though we are training within our notebook instance, we'll continue to use the S3 data location since it will allow us to easily transition to training in SageMaker's managed environment.

# %%
inputs = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-gluon-cifar10')
print('input spec (in this case, just an S3 path): {}'.format(inputs))
# Out:
# input spec (in this case, just an S3 path): s3://sagemaker-us-east-1-437242975833/data/DEMO-gluon-cifar10

# %% [markdown]
# ---
#
# ## Script
#
# We need to provide a training script that can run on the SageMaker platform. When SageMaker calls your function, it will pass in arguments that describe the training environment. Check the script below to see how this works.
#
# The network itself is a pre-built version contained in the [Gluon Model Zoo](https://mxnet.incubator.apache.org/versions/master/api/python/gluon/model_zoo.html).

# %%
# !cat 'cifar10.py'
# Out:
# from __future__ import print_function
#
# import json
# import logging
# import os
# import time
#
# import mxnet as mx
# from mxnet import autograd as ag
# from mxnet import gluon
# from mxnet.gluon.model_zoo import vision as models
#
#
# # ------------------------------------------------------------ #
# # Training methods                                             #
# # ------------------------------------------------------------ #
#
# def train(current_host, hosts, num_cpus, num_gpus, channel_input_dirs, model_dir, hyperparameters, **kwargs):
#     # retrieve the hyperparameters we set in notebook (with some defaults)
#     batch_size = hyperparameters.get('batch_size', 128)
#     epochs = hyperparameters.get('epochs', 100)
#     learning_rate = hyperparameters.get('learning_rate', 0.1)
#     momentum = hyperparameters.get('momentum', 0.9)
#     log_interval = hyperparameters.get('log_interval', 1)
#     wd = hyperparameters.get('wd', 0.0001)
#
#     if len(hosts) == 1:
#         kvstore = 'device' if num_gpus > 0 else 'local'
#     else:
#         kvstore = 'dist_device_sync'
#
#     ctx = [mx.gpu(i) for i in range(num_gpus)] if num_gpus > 0 else [mx.cpu()]
#     net = models.get_model('resnet34_v2', ctx=ctx, pretrained=False, classes=10)
#     batch_size *= max(1, len(ctx))
#
#     # load training and validation data
#     # we use the gluon.data.vision.CIFAR10 class because of its built in pre-processing logic,
#     # but point it at the location where SageMaker placed the data files, so it doesn't download them again.
#
#     part_index = 0
#     for i, host in enumerate(hosts):
#         if host == current_host:
#             part_index = i
#             break
#
#
#     data_dir = channel_input_dirs['training']
#     train_data = get_train_data(num_cpus, data_dir, batch_size, (3, 32, 32),
#                                 num_parts=len(hosts), part_index=part_index)
#     test_data = get_test_data(num_cpus, data_dir, batch_size, (3, 32, 32))
#
#     # Collect all parameters from net and its children, then initialize them.
#     net.initialize(mx.init.Xavier(magnitude=2), ctx=ctx)
#     # Trainer is for updating parameters with gradient.
#     trainer = gluon.Trainer(net.collect_params(), 'sgd',
#                             optimizer_params={'learning_rate': learning_rate, 'momentum': momentum, 'wd': wd},
#                             kvstore=kvstore)
#     metric = mx.metric.Accuracy()
#     loss = gluon.loss.SoftmaxCrossEntropyLoss()
#
#     best_accuracy = 0.0
#     for epoch in range(epochs):
#         # reset data iterator and metric at begining of epoch.
#         train_data.reset()
#         tic = time.time()
#         metric.reset()
#         btic = time.time()
#
#         for i, batch in enumerate(train_data):
#             data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
#             label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
#             outputs = []
#             Ls = []
#             with ag.record():
#                 for x, y in zip(data, label):
#                     z = net(x)
#                     L = loss(z, y)
#                     # store the loss and do backward after we have done forward
#                     # on all GPUs for better speed on multiple GPUs.
#                     Ls.append(L)
#                     outputs.append(z)
#                 for L in Ls:
#                     L.backward()
#             trainer.step(batch.data[0].shape[0])
#             metric.update(label, outputs)
#             if i % log_interval == 0 and i > 0:
#                 name, acc = metric.get()
#                 logging.info('Epoch [%d] Batch [%d]\tSpeed: %f samples/sec\t%s=%f' %
#                              (epoch, i, batch_size / (time.time() - btic), name, acc))
#             btic = time.time()
#
#         name, acc = metric.get()
#         logging.info('[Epoch %d] training: %s=%f' % (epoch, name, acc))
#         logging.info('[Epoch %d] time cost: %f' % (epoch, time.time() - tic))
#
#         name, val_acc = test(ctx, net, test_data)
#         logging.info('[Epoch %d] validation: %s=%f' % (epoch, name, val_acc))
#
#         # only save params on primary host
#         if current_host == hosts[0]:
#             if val_acc > best_accuracy:
#                 net.save_params('{}/model-{:0>4}.params'.format(model_dir, epoch))
#                 best_accuracy = val_acc
#
#     return net
#
#
# def save(net, model_dir):
#     # model_dir will be empty except on primary container
#     files = os.listdir(model_dir)
#     if files:
#         best = sorted(os.listdir(model_dir))[-1]
#         os.rename(os.path.join(model_dir, best), os.path.join(model_dir, 'model.params'))
#
#
# def get_data(path, augment, num_cpus, batch_size, data_shape, resize=-1, num_parts=1, part_index=0):
#     return mx.io.ImageRecordIter(
#         path_imgrec=path,
#         resize=resize,
#         data_shape=data_shape,
#         batch_size=batch_size,
#         rand_crop=augment,
#         rand_mirror=augment,
#         preprocess_threads=num_cpus,
#         num_parts=num_parts,
#         part_index=part_index)
#
#
# def get_test_data(num_cpus, data_dir, batch_size, data_shape, resize=-1):
#     return get_data(os.path.join(data_dir, "test.rec"), False, num_cpus, batch_size, data_shape, resize, 1, 0)
#
#
# def get_train_data(num_cpus, data_dir, batch_size, data_shape, resize=-1, num_parts=1, part_index=0):
#     return get_data(os.path.join(data_dir, "train.rec"), True, num_cpus, batch_size, data_shape, resize, num_parts,
#                     part_index)
#
#
# def test(ctx, net, test_data):
#     test_data.reset()
#     metric = mx.metric.Accuracy()
#
#     for i, batch in enumerate(test_data):
#         data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
#         label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
#         outputs = []
#         for x in data:
#             outputs.append(net(x))
#         metric.update(label, outputs)
#     return metric.get()
#
#
# # ------------------------------------------------------------ #
# # Hosting methods                                              #
# # ------------------------------------------------------------ #
#
# def model_fn(model_dir):
#     """
#     Load the gluon model. Called once when hosting service starts.
#
#     :param: model_dir The directory where model files are stored.
#     :return: a model (in this case a Gluon network)
#     """
#
#     net = models.get_model('resnet34_v2', ctx=mx.cpu(), pretrained=False, classes=10)
#     net.load_params('%s/model.params' % model_dir, ctx=mx.cpu())
#     return net
#
#
# def transform_fn(net, data, input_content_type, output_content_type):
#     """
#     Transform a request using the Gluon model. Called once per request.
#
#     :param net: The Gluon model.
#     :param data: The request payload.
#     :param input_content_type: The request content type.
#     :param output_content_type: The (desired) response content type.
#     :return: response payload and content type.
#     """
#     # we can use content types to vary input/output handling, but
#     # here we just assume json for both
#     parsed = json.loads(data)
#     nda = mx.nd.array(parsed)
#     output = net(nda)
#     prediction = mx.nd.argmax(output, axis=1)
#     response_body = json.dumps(prediction.asnumpy().tolist()[0])
#     return response_body, output_content_type

# %% [markdown]
# ---
#
# ## Train (Local Mode)
#
# The ```MXNet``` estimator will create our training job. To switch from training in SageMaker's managed environment to training within a notebook instance, just set `train_instance_type` to `local_gpu`.

# %%
m = MXNet('cifar10.py',
          role=role, 
          train_instance_count=1,
          train_instance_type='local_gpu',
          framework_version='1.1.0',
          hyperparameters={'batch_size': 1024,
                           'epochs': 5,
                           'learning_rate': 0.8,
                           'momentum': 0.9},
          py_version = "py3")

# %% [markdown]
# After we've constructed our `MXNet` object, we can fit it using the data we uploaded to S3. SageMaker makes sure our data is available in the local filesystem, so our training script can simply read the data from disk.

# %%
m.fit(inputs)
# Out:
# Creating tmpqioifl1x_algo-1-67dsm_1 ...
# Attaching to tmpqioifl1x_algo-1-67dsm_12mdone
# algo-1-67dsm_1  | 2019-07-15 20:35:30,378 INFO - root - running container entrypoint
# algo-1-67dsm_1  | 2019-07-15 20:35:30,379 INFO - root - starting train task
# algo-1-67dsm_1  | 2019-07-15 20:35:30,400 INFO - container_support.training - Training starting
# algo-1-67dsm_1  | 2019-07-15 20:35:30,758 INFO - mxnet_container.train - MXNetTrainingEnvironment: {'channels': {'training': {'TrainingInputMode': 'File'}}, '_ps_port': 8000, 'channel_dirs': {'training': '/opt/ml/input/data/training'}, 'current_host': 'algo-1-67dsm', 'resource_config': {'hosts': ['algo-1-67dsm'], 'current_host': 'algo-1-67dsm'}, '_scheduler_host': 'algo-1-67dsm', 'hyperparameters': {'batch_size': 1024, 'epochs': 5, 'momentum': 0.9, 'sagemaker_submit_directory': 's3://sagemaker-us-east-1-437242975833/sagemaker-mxnet-2019-07-15-20-32-44-985/source/sourcedir.tar.gz', 'sagemaker_job_name': 'sagemaker-mxnet-2019-07-15-20-32-44-985', 'sagemaker_program': 'cifar10.py', 'sagemaker_container_log_level': 20, 'sagemaker_region': 'us-east-1', 'learning_rate': 0.8, 'sagemaker_enable_cloudwatch_metrics': False}, 'sagemaker_region': 'us-east-1', '_ps_verbose': 0, 'user_requirements_file': None, 'user_script_name': 'cifar10.py', 'hosts': ['algo-1-67dsm'], 'code_dir': '/opt/ml/code', 'enable_cloudwatch_metrics': False, 'output_dir': '/opt/ml/output', 'base_dir': '/opt/ml', 'model_dir': '/opt/ml/model', 'input_config_dir': '/opt/ml/input/config', 'output_data_dir': '/opt/ml/output/data/', 'input_dir': '/opt/ml/input', 'container_log_level': 20, 'job_name': 'sagemaker-mxnet-2019-07-15-20-32-44-985', '_scheduler_ip': '172.18.0.2', 'available_gpus': 1, 'user_script_archive': 's3://sagemaker-us-east-1-437242975833/sagemaker-mxnet-2019-07-15-20-32-44-985/source/sourcedir.tar.gz', 'available_cpus': 16}
# algo-1-67dsm_1  | Downloading s3://sagemaker-us-east-1-437242975833/sagemaker-mxnet-2019-07-15-20-32-44-985/source/sourcedir.tar.gz to /tmp/script.tar.gz
# algo-1-67dsm_1  | 2019-07-15 20:35:30,772 INFO - botocore.credentials - Found credentials in environment variables.
# algo-1-67dsm_1  | 2019-07-15 20:35:31,273 INFO - mxnet_container.train - Starting distributed training task
# algo-1-67dsm_1  | /usr/local/lib/python3.5/dist-packages/mxnet_container/train.py:178: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
# algo-1-67dsm_1  |   train_args = inspect.getargspec(user_module.train)
# algo-1-67dsm_1  | [20:35:31] src/io/iter_image_recordio_2.cc:170: ImageRecordIOParser2: /opt/ml/input/data/training/train.rec, use 7 threads for decoding..
# algo-1-67dsm_1  | [20:35:32] src/io/iter_image_recordio_2.cc:170: ImageRecordIOParser2: /opt/ml/input/data/training/test.rec, use 7 threads for decoding..
# algo-1-67dsm_1  | [20:35:36] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:107: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# algo-1-67dsm_1  | 2019-07-15 20:35:38,855 INFO - root - Epoch [0] Batch [1]	Speed: 6816.759191 samples/sec	accuracy=0.116211
# algo-1-67dsm_1  | 2019-07-15 20:35:39,004 INFO - root - Epoch [0] Batch [2]	Speed: 6888.700994 samples/sec	accuracy=0.110026
# algo-1-67dsm_1  | 2019-07-15 20:35:39,153 INFO - root - Epoch [0] Batch [3]	Speed: 6903.161006 samples/sec	accuracy=0.108887
# algo-1-67dsm_1  | 2019-07-15 20:35:42,243 INFO - root - Epoch [0] Batch [23]	Speed: 6326.324924 samples/sec	accuracy=0.108561
# algo-1-67dsm_1  | 2019-07-15 20:35:42,390 INFO - root - Epoch [0] Batch [24]	Speed: 6939.903206 samples/sec	accuracy=0.108320
# algo-1-67dsm_1  | 2019-07-15 20:35:42,548 INFO - root - Epoch [0] Batch [25]	Speed: 6517.292270 samples/sec	accuracy=0.108661
# algo-1-67dsm_1  | 2019-07-15 20:35:42,717 INFO - root - Epoch [0] Batch [26]	Speed: 6066.723586 samples/sec	accuracy=0.109122
# algo-1-67dsm_1  | 2019-07-15 20:35:42,870 INFO - root - Epoch [0] Batch [27]	Speed: 6682.849757 samples/sec	accuracy=0.109584
# algo-1-67dsm_1  | 2019-07-15 20:35:43,017 INFO - root - Epoch [0] Batch [28]	Speed: 6964.119184 samples/sec	accuracy=0.109510
# algo-1-67dsm_1  | 2019-07-15 20:35:43,171 INFO - root - Epoch [0] Batch [29]	Speed: 6653.953510 samples/sec	accuracy=0.109798
# algo-1-67dsm_1  | 2019-07-15 20:35:43,342 INFO - root - Epoch [0] Batch [30]	Speed: 6008.997890 samples/sec	accuracy=0.109848
# algo-1-67dsm_1  | 2019-07-15 20:35:43,494 INFO - root - Epoch [0] Batch [31]	Speed: 6763.174190 samples/sec	accuracy=0.110229
# algo-1-67dsm_1  | 2019-07-15 20:35:43,644 INFO - root - Epoch [0] Batch [32]	Speed: 6846.260504 samples/sec	accuracy=0.110322
# algo-1-67dsm_1  | 2019-07-15 20:35:43,812 INFO - root - Epoch [0] Batch [33]	Speed: 6071.903901 samples/sec	accuracy=0.110237
# algo-1-67dsm_1  | 2019-07-15 20:35:43,963 INFO - root - Epoch [0] Batch [34]	Speed: 6819.118598 samples/sec	accuracy=0.110184
# algo-1-67dsm_1  | 2019-07-15 20:35:44,112 INFO - root - Epoch [0] Batch [35]	Speed: 6850.049436 samples/sec	accuracy=0.110379
# algo-1-67dsm_1  | 2019-07-15 20:35:44,273 INFO - root - Epoch [0] Batch [36]	Speed: 6403.641674 samples/sec	accuracy=0.110536
# algo-1-67dsm_1  | 2019-07-15 20:35:44,438 INFO - root - Epoch [0] Batch [37]	Speed: 6208.080389 samples/sec	accuracy=0.111045
# algo-1-67dsm_1  | 2019-07-15 20:35:44,585 INFO - root - Epoch [0] Batch [38]	Speed: 6977.333316 samples/sec	accuracy=0.111203
# algo-1-67dsm_1  | 2019-07-15 20:35:44,743 INFO - root - Epoch [0] Batch [39]	Speed: 6468.197605 samples/sec	accuracy=0.112134
# algo-1-67dsm_1  | 2019-07-15 20:35:44,911 INFO - root - Epoch [0] Batch [40]	Speed: 6117.638013 samples/sec	accuracy=0.112686
# algo-1-67dsm_1  | 2019-07-15 20:35:45,060 INFO - root - Epoch [0] Batch [41]	Speed: 6878.484986 samples/sec	accuracy=0.113351
# algo-1-67dsm_1  | 2019-07-15 20:35:45,220 INFO - root - Epoch [0] Batch [42]	Speed: 6392.490435 samples/sec	accuracy=0.113281
# algo-1-67dsm_1  | 2019-07-15 20:35:45,381 INFO - root - Epoch [0] Batch [43]	Speed: 6384.726631 samples/sec	accuracy=0.113503
# algo-1-67dsm_1  | 2019-07-15 20:35:45,529 INFO - root - Epoch [0] Batch [44]	Speed: 6904.692487 samples/sec	accuracy=0.114084
# algo-1-67dsm_1  | 2019-07-15 20:35:45,697 INFO - root - Epoch [0] Batch [45]	Speed: 6112.257619 samples/sec	accuracy=0.114215
# algo-1-67dsm_1  | 2019-07-15 20:35:45,850 INFO - root - Epoch [0] Batch [46]	Speed: 6691.554082 samples/sec	accuracy=0.114133
# algo-1-67dsm_1  | 2019-07-15 20:35:46,016 INFO - root - Epoch [0] Batch [47]	Speed: 6179.764600 samples/sec	accuracy=0.114807
# algo-1-67dsm_1  | 2019-07-15 20:35:46,178 INFO - root - Epoch [0] Batch [48]	Speed: 6322.553206 samples/sec	accuracy=0.115573
# algo-1-67dsm_1  | 2019-07-15 20:35:46,179 INFO - root - [Epoch 0] training: accuracy=0.115573
# algo-1-67dsm_1  | 2019-07-15 20:35:46,179 INFO - root - [Epoch 0] time cost: 13.321810
# algo-1-67dsm_1  | 2019-07-15 20:35:46,812 INFO - root - [Epoch 0] validation: accuracy=0.124414
# algo-1-67dsm_1  | 2019-07-15 20:35:47,114 INFO - root - Epoch [1] Batch [1]	Speed: 6882.177342 samples/sec	accuracy=0.150879
# algo-1-67dsm_1  | 2019-07-15 20:35:47,276 INFO - root - Epoch [1] Batch [2]	Speed: 6314.856119 samples/sec	accuracy=0.156901
# algo-1-67dsm_1  | 2019-07-15 20:35:47,434 INFO - root - Epoch [1] Batch [3]	Speed: 6500.375793 samples/sec	accuracy=0.158447
# algo-1-67dsm_1  | 2019-07-15 20:35:47,580 INFO - root - Epoch [1] Batch [4]	Speed: 7019.572082 samples/sec	accuracy=0.161719
# algo-1-67dsm_1  | 2019-07-15 20:35:47,729 INFO - root - Epoch [1] Batch [5]	Speed: 6880.810157 samples/sec	accuracy=0.163249
# algo-1-67dsm_1  | 2019-07-15 20:35:47,877 INFO - root - Epoch [1] Batch [6]	Speed: 6923.056446 samples/sec	accuracy=0.166713
# algo-1-67dsm_1  | 2019-07-15 20:35:48,043 INFO - root - Epoch [1] Batch [7]	Speed: 6184.293784 samples/sec	accuracy=0.169189
# algo-1-67dsm_1  | 2019-07-15 20:35:48,213 INFO - root - Epoch [1] Batch [8]	Speed: 6033.164108 samples/sec	accuracy=0.172092
# algo-1-67dsm_1  | 2019-07-15 20:35:48,366 INFO - root - Epoch [1] Batch [9]	Speed: 6664.029939 samples/sec	accuracy=0.171094
# algo-1-67dsm_1  | 2019-07-15 20:35:48,524 INFO - root - Epoch [1] Batch [10]	Speed: 6495.519337 samples/sec	accuracy=0.172940
# algo-1-67dsm_1  | 2019-07-15 20:35:48,689 INFO - root - Epoch [1] Batch [11]	Speed: 6236.602523 samples/sec	accuracy=0.174154
# algo-1-67dsm_1  | 2019-07-15 20:36:01,487 INFO - root - Epoch [2] Batch [41]	Speed: 6563.615282 samples/sec	accuracy=0.234724
# algo-1-67dsm_1  | 2019-07-15 20:36:01,657 INFO - root - Epoch [2] Batch [42]	Speed: 6026.341129 samples/sec	accuracy=0.234988
# algo-1-67dsm_1  | 2019-07-15 20:36:01,814 INFO - root - Epoch [2] Batch [43]	Speed: 6554.630162 samples/sec	accuracy=0.235463
# algo-1-67dsm_1  | 2019-07-15 20:36:01,983 INFO - root - Epoch [2] Batch [44]	Speed: 6061.338241 samples/sec	accuracy=0.236263
# algo-1-67dsm_1  | 2019-07-15 20:36:02,139 INFO - root - Epoch [2] Batch [45]	Speed: 6571.629464 samples/sec	accuracy=0.236880
# algo-1-67dsm_1  | 2019-07-15 20:36:02,306 INFO - root - Epoch [2] Batch [46]	Speed: 6115.747702 samples/sec	accuracy=0.237471
# algo-1-67dsm_1  | 2019-07-15 20:36:02,463 INFO - root - Epoch [2] Batch [47]	Speed: 6566.204194 samples/sec	accuracy=0.238363
# algo-1-67dsm_1  | 2019-07-15 20:36:02,631 INFO - root - Epoch [2] Batch [48]	Speed: 6091.201793 samples/sec	accuracy=0.238799
# algo-1-67dsm_1  | 2019-07-15 20:36:02,631 INFO - root - [Epoch 2] training: accuracy=0.238799
# algo-1-67dsm_1  | 2019-07-15 20:36:02,631 INFO - root - [Epoch 2] time cost: 7.610042
# algo-1-67dsm_1  | 2019-07-15 20:36:03,248 INFO - root - [Epoch 2] validation: accuracy=0.208105
# algo-1-67dsm_1  | 2019-07-15 20:36:03,449 INFO - root - Epoch [3] Batch [1]	Speed: 6872.365513 samples/sec	accuracy=0.253418
# algo-1-67dsm_1  | 2019-07-15 20:36:03,599 INFO - root - Epoch [3] Batch [2]	Speed: 6815.688256 samples/sec	accuracy=0.251302
# algo-1-67dsm_1  | 2019-07-15 20:36:03,765 INFO - root - Epoch [3] Batch [3]	Speed: 6191.970267 samples/sec	accuracy=0.249756
# algo-1-67dsm_1  | 2019-07-15 20:36:03,929 INFO - root - Epoch [3] Batch [4]	Speed: 6272.085424 samples/sec	accuracy=0.251563
# algo-1-67dsm_1  | 2019-07-15 20:36:04,076 INFO - root - Epoch [3] Batch [5]	Speed: 6948.312406 samples/sec	accuracy=0.252441
# algo-1-67dsm_1  | 2019-07-15 20:36:04,234 INFO - root - Epoch [3] Batch [6]	Speed: 6501.733752 samples/sec	accuracy=0.254325
# algo-1-67dsm_1  | 2019-07-15 20:36:04,403 INFO - root - Epoch [3] Batch [7]	Speed: 6074.720760 samples/sec	accuracy=0.255615
# algo-1-67dsm_1  | 2019-07-15 20:36:04,561 INFO - root - Epoch [3] Batch [8]	Speed: 6458.374065 samples/sec	accuracy=0.254883
# algo-1-67dsm_1  | 2019-07-15 20:36:04,728 INFO - root - Epoch [3] Batch [9]	Speed: 6150.305292 samples/sec	accuracy=0.255957
# algo-1-67dsm_1  | 2019-07-15 20:36:04,883 INFO - root - Epoch [3] Batch [10]	Speed: 6610.876238 samples/sec	accuracy=0.257013
# algo-1-67dsm_1  | 2019-07-15 20:36:05,052 INFO - root - Epoch [3] Batch [11]	Speed: 6067.786373 samples/sec	accuracy=0.259766
# algo-1-67dsm_1  | 2019-07-15 20:36:05,206 INFO - root - Epoch [3] Batch [12]	Speed: 6679.690160 samples/sec	accuracy=0.261418
# algo-1-67dsm_1  | 2019-07-15 20:36:05,374 INFO - root - Epoch [3] Batch [13]	Speed: 6085.876403 samples/sec	accuracy=0.261719
# algo-1-67dsm_1  | 2019-07-15 20:36:05,524 INFO - root - Epoch [3] Batch [14]	Speed: 6844.100398 samples/sec	accuracy=0.263477
# algo-1-67dsm_1  | 2019-07-15 20:36:05,672 INFO - root - Epoch [3] Batch [15]	Speed: 6942.359864 samples/sec	accuracy=0.266113
# algo-1-67dsm_1  | 2019-07-15 20:36:05,820 INFO - root - Epoch [3] Batch [16]	Speed: 6892.514938 samples/sec	accuracy=0.265970
# algo-1-67dsm_1  | 2019-07-15 20:36:05,967 INFO - root - Epoch [3] Batch [17]	Speed: 7005.969059 samples/sec	accuracy=0.267036
# algo-1-67dsm_1  | 2019-07-15 20:36:06,117 INFO - root - Epoch [3] Batch [18]	Speed: 6848.203582 samples/sec	accuracy=0.269583
# algo-1-67dsm_1  | 2019-07-15 20:36:06,264 INFO - root - Epoch [3] Batch [19]	Speed: 6974.308200 samples/sec	accuracy=0.270215
# algo-1-67dsm_1  | 2019-07-15 20:36:06,412 INFO - root - Epoch [3] Batch [20]	Speed: 6919.409286 samples/sec	accuracy=0.270415
# algo-1-67dsm_1  | 2019-07-15 20:36:06,559 INFO - root - Epoch [3] Batch [21]	Speed: 6965.711726 samples/sec	accuracy=0.269886
# algo-1-67dsm_1  | 2019-07-15 20:36:06,708 INFO - root - Epoch [3] Batch [22]	Speed: 6857.596096 samples/sec	accuracy=0.269361
# algo-1-67dsm_1  | 2019-07-15 20:36:06,855 INFO - root - Epoch [3] Batch [23]	Speed: 7015.925694 samples/sec	accuracy=0.268148
# algo-1-67dsm_1  | 2019-07-15 20:36:07,004 INFO - root - Epoch [3] Batch [24]	Speed: 6880.479468 samples/sec	accuracy=0.266797
# algo-1-67dsm_1  | 2019-07-15 20:36:07,151 INFO - root - Epoch [3] Batch [25]	Speed: 6966.400924 samples/sec	accuracy=0.266376
# algo-1-67dsm_1  | 2019-07-15 20:36:07,299 INFO - root - Epoch [3] Batch [26]	Speed: 6901.852018 samples/sec	accuracy=0.266927
# algo-1-67dsm_1  | 2019-07-15 20:36:07,446 INFO - root - Epoch [3] Batch [27]	Speed: 6988.277333 samples/sec	accuracy=0.268136
# algo-1-67dsm_1  | 2019-07-15 20:36:07,596 INFO - root - Epoch [3] Batch [28]	Speed: 6845.638516 samples/sec	accuracy=0.268925
# algo-1-67dsm_1  | 2019-07-15 20:36:07,742 INFO - root - Epoch [3] Batch [29]	Speed: 7022.292139 samples/sec	accuracy=0.269108
# algo-1-67dsm_1  | 2019-07-15 20:36:07,891 INFO - root - Epoch [3] Batch [30]	Speed: 6887.287039 samples/sec	accuracy=0.269626
# algo-1-67dsm_1  | 2019-07-15 20:36:08,038 INFO - root - Epoch [3] Batch [31]	Speed: 6945.301166 samples/sec	accuracy=0.269897
# algo-1-67dsm_1  | 2019-07-15 20:36:08,188 INFO - root - Epoch [3] Batch [32]	Speed: 6851.207698 samples/sec	accuracy=0.269709
# algo-1-67dsm_1  | 2019-07-15 20:36:08,334 INFO - root - Epoch [3] Batch [33]	Speed: 7008.141084 samples/sec	accuracy=0.269503
# algo-1-67dsm_1  | 2019-07-15 20:36:08,484 INFO - root - Epoch [3] Batch [34]	Speed: 6857.563249 samples/sec	accuracy=0.268722
# algo-1-67dsm_1  | 2019-07-15 20:36:08,631 INFO - root - Epoch [3] Batch [35]	Speed: 6967.644085 samples/sec	accuracy=0.267849
# algo-1-67dsm_1  | 2019-07-15 20:36:08,780 INFO - root - Epoch [3] Batch [36]	Speed: 6902.595196 samples/sec	accuracy=0.268185
# algo-1-67dsm_1  | 2019-07-15 20:36:08,926 INFO - root - Epoch [3] Batch [37]	Speed: 6975.101048 samples/sec	accuracy=0.268940
# algo-1-67dsm_1  | 2019-07-15 20:36:09,076 INFO - root - Epoch [3] Batch [38]	Speed: 6867.288905 samples/sec	accuracy=0.269907
# algo-1-67dsm_1  | 2019-07-15 20:36:09,222 INFO - root - Epoch [3] Batch [39]	Speed: 7019.973646 samples/sec	accuracy=0.269751
# algo-1-67dsm_1  | 2019-07-15 20:36:09,371 INFO - root - Epoch [3] Batch [40]	Speed: 6883.567135 samples/sec	accuracy=0.270079
# algo-1-67dsm_1  | 2019-07-15 20:36:09,518 INFO - root - Epoch [3] Batch [41]	Speed: 6950.955009 samples/sec	accuracy=0.270647
# algo-1-67dsm_1  | 2019-07-15 20:36:09,669 INFO - root - Epoch [3] Batch [42]	Speed: 6794.952706 samples/sec	accuracy=0.270962
# algo-1-67dsm_1  | 2019-07-15 20:36:09,816 INFO - root - Epoch [3] Batch [43]	Speed: 6998.491599 samples/sec	accuracy=0.271063
# algo-1-67dsm_1  | 2019-07-15 20:36:09,965 INFO - root - Epoch [3] Batch [44]	Speed: 6845.005731 samples/sec	accuracy=0.271788
# algo-1-67dsm_1  | 2019-07-15 20:36:10,121 INFO - root - Epoch [3] Batch [45]	Speed: 6583.152666 samples/sec	accuracy=0.272100
# algo-1-67dsm_1  | 2019-07-15 20:36:10,284 INFO - root - Epoch [3] Batch [46]	Speed: 6279.632629 samples/sec	accuracy=0.272461
# algo-1-67dsm_1  | 2019-07-15 20:36:10,438 INFO - root - Epoch [3] Batch [47]	Speed: 6677.114805 samples/sec	accuracy=0.272888
# algo-1-67dsm_1  | 2019-07-15 20:36:10,604 INFO - root - Epoch [3] Batch [48]	Speed: 6166.287588 samples/sec	accuracy=0.273358
# algo-1-67dsm_1  | 2019-07-15 20:36:10,605 INFO - root - [Epoch 3] training: accuracy=0.273358
# algo-1-67dsm_1  | 2019-07-15 20:36:10,605 INFO - root - [Epoch 3] time cost: 7.356472
# algo-1-67dsm_1  | 2019-07-15 20:36:11,189 INFO - root - [Epoch 3] validation: accuracy=0.284071
# algo-1-67dsm_1  | 2019-07-15 20:36:11,488 INFO - root - Epoch [4] Batch [1]	Speed: 6845.780363 samples/sec	accuracy=0.288086
# algo-1-67dsm_1  | 2019-07-15 20:36:11,643 INFO - root - Epoch [4] Batch [2]	Speed: 6612.738890 samples/sec	accuracy=0.291667
# algo-1-67dsm_1  | 2019-07-15 20:36:11,808 INFO - root - Epoch [4] Batch [3]	Speed: 6217.651745 samples/sec	accuracy=0.290039
# algo-1-67dsm_1  | 2019-07-15 20:36:11,962 INFO - root - Epoch [4] Batch [4]	Speed: 6661.921279 samples/sec	accuracy=0.285938
# algo-1-67dsm_1  | 2019-07-15 20:36:12,129 INFO - root - Epoch [4] Batch [5]	Speed: 6149.873774 samples/sec	accuracy=0.290690
# algo-1-67dsm_1  | 2019-07-15 20:36:12,277 INFO - root - Epoch [4] Batch [6]	Speed: 6938.243983 samples/sec	accuracy=0.290318
# algo-1-67dsm_1  | 2019-07-15 20:36:12,428 INFO - root - Epoch [4] Batch [7]	Speed: 6786.170479 samples/sec	accuracy=0.288940
# algo-1-67dsm_1  | 2019-07-15 20:36:12,576 INFO - root - Epoch [4] Batch [8]	Speed: 6905.891512 samples/sec	accuracy=0.289931
# algo-1-67dsm_1  | 2019-07-15 20:36:12,725 INFO - root - Epoch [4] Batch [9]	Speed: 6897.728624 samples/sec	accuracy=0.291309
# algo-1-67dsm_1  | 2019-07-15 20:36:12,875 INFO - root - Epoch [4] Batch [10]	Speed: 6836.561631 samples/sec	accuracy=0.291016
# algo-1-67dsm_1  | 2019-07-15 20:36:13,039 INFO - root - Epoch [4] Batch [11]	Speed: 6236.774592 samples/sec	accuracy=0.291260
# algo-1-67dsm_1  | 2019-07-15 20:36:13,194 INFO - root - Epoch [4] Batch [12]	Speed: 6625.163002 samples/sec	accuracy=0.291466
# algo-1-67dsm_1  | 2019-07-15 20:36:13,357 INFO - root - Epoch [4] Batch [13]	Speed: 6290.089257 samples/sec	accuracy=0.290667
# algo-1-67dsm_1  | 2019-07-15 20:36:13,515 INFO - root - Epoch [4] Batch [14]	Speed: 6471.179746 samples/sec	accuracy=0.291016
# algo-1-67dsm_1  | 2019-07-15 20:36:13,682 INFO - root - Epoch [4] Batch [15]	Speed: 6155.885252 samples/sec	accuracy=0.292847
# algo-1-67dsm_1  | 2019-07-15 20:36:13,838 INFO - root - Epoch [4] Batch [16]	Speed: 6582.214393 samples/sec	accuracy=0.292624
# algo-1-67dsm_1  | 2019-07-15 20:36:14,003 INFO - root - Epoch [4] Batch [17]	Speed: 6199.925364 samples/sec	accuracy=0.292480
# algo-1-67dsm_1  | 2019-07-15 20:36:14,160 INFO - root - Epoch [4] Batch [18]	Speed: 6548.184479 samples/sec	accuracy=0.293431
# algo-1-67dsm_1  | 2019-07-15 20:36:17,417 INFO - root - Epoch [4] Batch [38]	Speed: 6018.926193 samples/sec	accuracy=0.297701
# algo-1-67dsm_1  | 2019-07-15 20:36:17,577 INFO - root - Epoch [4] Batch [39]	Speed: 6415.943474 samples/sec	accuracy=0.297607
# algo-1-67dsm_1  | 2019-07-15 20:36:17,747 INFO - root - Epoch [4] Batch [40]	Speed: 6010.906900 samples/sec	accuracy=0.298114
# algo-1-67dsm_1  | 2019-07-15 20:36:17,904 INFO - root - Epoch [4] Batch [41]	Speed: 6546.038734 samples/sec	accuracy=0.297945
# algo-1-67dsm_1  | 2019-07-15 20:36:18,073 INFO - root - Epoch [4] Batch [42]	Speed: 6052.156453 samples/sec	accuracy=0.297352
# algo-1-67dsm_1  | 2019-07-15 20:36:18,230 INFO - root - Epoch [4] Batch [43]	Speed: 6555.070330 samples/sec	accuracy=0.298118
# algo-1-67dsm_1  | 2019-07-15 20:36:18,399 INFO - root - Epoch [4] Batch [44]	Speed: 6071.303080 samples/sec	accuracy=0.298589
# algo-1-67dsm_1  | 2019-07-15 20:36:18,553 INFO - root - Epoch [4] Batch [45]	Speed: 6626.144227 samples/sec	accuracy=0.298361
# algo-1-67dsm_1  | 2019-07-15 20:36:18,722 INFO - root - Epoch [4] Batch [46]	Speed: 6078.374544 samples/sec	accuracy=0.298267
# algo-1-67dsm_1  | 2019-07-15 20:36:18,877 INFO - root - Epoch [4] Batch [47]	Speed: 6594.493588 samples/sec	accuracy=0.298767
# algo-1-67dsm_1  | 2019-07-15 20:36:19,046 INFO - root - Epoch [4] Batch [48]	Speed: 6094.088471 samples/sec	accuracy=0.298868
# algo-1-67dsm_1  | 2019-07-15 20:36:19,046 INFO - root - [Epoch 4] training: accuracy=0.298868
# algo-1-67dsm_1  | 2019-07-15 20:36:19,046 INFO - root - [Epoch 4] time cost: 7.759808
# algo-1-67dsm_1  | 2019-07-15 20:36:19,661 INFO - root - [Epoch 4] validation: accuracy=0.298926
# tmpqioifl1x_algo-1-67dsm_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ---
#
# ## Host
#
# After training, we use the MXNet estimator object to deploy an endpoint. Because we trained locally, we'll also deploy the endpoint locally.  The predictor object returned by `deploy` lets us call the endpoint and perform inference on our sample images.

# %%
predictor = m.deploy(initial_instance_count=1, instance_type='local_gpu')
# Out:
# Attaching to tmp2g0l4dal_algo-1-zl0u5_1
# algo-1-zl0u5_1  | 2019-07-15 20:37:49,544 INFO - root - running container entrypoint
# algo-1-zl0u5_1  | 2019-07-15 20:37:49,545 INFO - root - starting serve task
# algo-1-zl0u5_1  | 2019-07-15 20:37:49,545 INFO - container_support.serving - reading config
# algo-1-zl0u5_1  | Downloading s3://sagemaker-us-east-1-437242975833/sagemaker-mxnet-2019-07-15-20-32-44-985/sourcedir.tar.gz to /tmp/script.tar.gz
# algo-1-zl0u5_1  | 2019-07-15 20:37:49,575 INFO - botocore.credentials - Found credentials in environment variables.
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,034 INFO - container_support.serving - loading framework-specific dependencies
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,382 INFO - container_support.serving - starting nginx
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,397 INFO - container_support.serving - starting gunicorn
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,400 INFO - container_support.serving - inference server started. waiting on processes: {32, 31}
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [32] [INFO] Starting gunicorn 19.9.0
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [32] [INFO] Listening at: unix:/tmp/gunicorn.sock (32)
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [32] [INFO] Using worker: gevent
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [51] [INFO] Booting worker with pid: 51
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [52] [INFO] Booting worker with pid: 52
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [54] [INFO] Booting worker with pid: 54
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,750 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [59] [INFO] Booting worker with pid: 59
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,763 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,773 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,787 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [92] [INFO] Booting worker with pid: 92
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [93] [INFO] Booting worker with pid: 93
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,900 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:50,913 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [112] [INFO] Booting worker with pid: 112
# algo-1-zl0u5_1  | [2019-07-15 20:37:50 +0000] [115] [INFO] Booting worker with pid: 115
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,028 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,041 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [135] [INFO] Booting worker with pid: 135
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,109 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,113 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,126 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,136 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [170] [INFO] Booting worker with pid: 170
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [172] [INFO] Booting worker with pid: 172
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [174] [INFO] Booting worker with pid: 174
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,271 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,285 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,296 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,331 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [197] [INFO] Booting worker with pid: 197
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [216] [INFO] Booting worker with pid: 216
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,393 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,415 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [235] [INFO] Booting worker with pid: 235
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,494 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [2019-07-15 20:37:51 +0000] [237] [INFO] Booting worker with pid: 237
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,570 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,573 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,579 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,589 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,589 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,590 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,604 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,725 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,741 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,791 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,791 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,812 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,841 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,873 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | [20:37:51] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,901 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,918 INFO - container_support.serving - creating Server instance
# algo-1-zl0u5_1  | 2019-07-15 20:37:51,969 INFO - container_support.serving - importing user module
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,059 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,070 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,098 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,211 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,255 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,395 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | 2019-07-15 20:37:52,395 INFO - container_support.serving - returning initialized server
# algo-1-zl0u5_1  | [20:37:52] src/engine/engine.cc:55: MXNet start using engine: NaiveEngine
# !

# %% [markdown]
# ### Evaluate
#
# We'll use these CIFAR-10 sample images to test the service:
#
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/airplane1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/automobile1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/bird1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/cat1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/deer1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/dog1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/frog1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/horse1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/ship1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/truck1.png" />

# %%
# load the CIFAR-10 samples, and convert them into format we can use with the prediction endpoint
from cifar10_utils import read_images

filenames = ['images/airplane1.png',
             'images/bird1.png',
             'images/cat1.png',
             'images/deer1.png',
             'images/dog1.png',
             'images/frog1.png',
             'images/horse1.png',
             'images/ship1.png',
             'images/truck1.png',
             'images/test.png',
             'images/airplane.png',
             'images/frogadded.png']

image_data = read_images(filenames)

# %% [markdown]
# The predictor runs inference on our input data and returns the predicted class label (as a float value, so we convert to int for display).

# %%
for i, img in enumerate(image_data):
    response = predictor.predict(img)
    print('image {}: class: {}'.format(i, int(response)))
# Out:
# image 0: class: 8
# image 1: class: 7
# image 2: class: 5
# image 3: class: 6
# image 4: class: 5
# image 5: class: 5
# image 6: class: 7
# image 7: class: 8
# image 8: class: 1
# image 9: class: 5
# image 10: class: 7
# image 11: class: 6

# %% [markdown]
# ---
#
# ## Cleanup
#
# After you have finished with this example, remember to delete the prediction endpoint.  Only one local endpoint can be running at a time.

# %%
m.delete_endpoint()
# Out:
# Gracefully stopping... (press Ctrl+C again to force)
